# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\kavya\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: jinja2>=3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.57.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.29.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: cloudpickle in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.7.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.22.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.13.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\kavya\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (23.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\kavya\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kavya\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\kavya\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kavya\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.17.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.3)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (67.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2023.11.17)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.9.0)
# Requirement already satisfied: retrying in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kavya\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: six in c:\users\kavya\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\kavya\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kavya\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\kavya\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\kavya\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\kavya\anaconda3\lib\site-packages (from scipy) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kavya\anaconda3\lib\site-packages (1.4.2)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.0-cp311-cp311-win_amd64.whl (11.0 MB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kavya\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kavya\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kavya\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.2
#     Uninstalling scikit-learn-1.4.2:
#       Successfully uninstalled scikit-learn-1.4.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Kavya\\anaconda3\\Lib\\site-packages\\~=learn\\.libs\\msvcp140.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip install --upgrade pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\kavya\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: jinja2>=3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.5.0)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.57.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.29.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: cloudpickle in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (3.7.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (5.22.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.13.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\kavya\anaconda3\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\kavya\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (23.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Collecting scikit-learn>1.4.0 (from pycaret)
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\kavya\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kavya\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\kavya\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kavya\anaconda3\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\kavya\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\kavya\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kavya\anaconda3\lib\site-packages (from pandas<2.2.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.17.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.3)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\kavya\anaconda3\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\kavya\anaconda3\lib\site-packages (from pmdarima>=2.0.4->pycaret) (67.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kavya\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2023.11.17)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.9.0)
# Requirement already satisfied: retrying in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\kavya\anaconda3\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\kavya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kavya\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kavya\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kavya\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: six in c:\users\kavya\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\kavya\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\kavya\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kavya\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\kavya\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\kavya\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.0
#     Uninstalling scikit-learn-1.5.0:
#       Successfully uninstalled scikit-learn-1.5.0
# Successfully installed scikit-learn-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from pycaret.classification import *

# %%
data = pd.read_csv(r"C:\Users\Kavya\Downloads\creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
fraud_check=pd.value_counts(data['Class'],sort=True)
fraud_check.plot(kind='bar',rot=0,color='b')
plt.title("Normal and Fraud Distribution")
plt.xlabel("Class")
plt.ylabel("Frequency")
labels=['Normal','Fraud']
plt.xticks(range(2),labels)
plt.show()

# %%
fraud_people=data[data['Class']==1]
normal_people=data[data['Class']==0]

# %%
fraud_people.shape
# Out:
# (492, 31)

# %%
normal_people.shape
# Out:
# (284315, 31)

# %%
fraud_people['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal_people['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
data.hist(figsize=(20,20),color='pink')
plt.show()

# %%
graph, (plot1, plot2) = plt.subplots(2,1,sharex= True) # sharex is used to check that graph donot overlapp
graph.suptitle('Average amount per class')
bins = 70

plot1.hist(fraud_people['Amount'] , bins = bins)
plot1.set_title('Fraud Amount')

plot2.hist(normal_people['Amount'] , bins = bins)
plot2.set_title('Normal Amount')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.yscale('log')
plt.show();

# %%
data.corr().head()
# Out:
#           Time            V1            V2            V3            V4  \
# Time  1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1    0.117396  1.000000e+00  3.777823e-12 -2.118614e-12 -1.733159e-13
# V2   -0.010593  3.777823e-12  1.000000e+00  2.325661e-12 -2.314981e-12
# V3   -0.419618 -2.118614e-12  2.325661e-12  1.000000e+00  2.046235e-13
# V4   -0.105260 -1.733159e-13 -2.314981e-12  2.046235e-13  1.000000e+00
#
#                 V5            V6            V7            V8            V9  \
# Time  1.730721e-01 -6.301647e-02  8.471437e-02 -3.694943e-02 -8.660434e-03
# V1   -3.473231e-12 -1.306165e-13 -1.116494e-13  2.114527e-12  3.016285e-14
# V2   -1.831952e-12  9.438444e-13  5.403436e-12  2.133785e-14  3.238513e-13
# V3   -4.032993e-12 -1.574471e-13  3.405586e-12 -1.272385e-12 -6.812351e-13
# V4   -2.552389e-13  1.084041e-12  8.135064e-13  7.334818e-13 -7.143069e-13
#
#       ...           V21           V22           V23           V24  \
# Time  ...  4.473573e-02  1.440591e-01  5.114236e-02 -1.618187e-02
# V1    ... -3.276238e-12  2.281863e-12 -2.969746e-12 -1.029876e-12
# V2    ...  2.280202e-12 -2.548560e-13 -4.856120e-12  6.431308e-13
# V3    ...  6.736294e-13 -8.909339e-13  4.147209e-12  3.407636e-12
# V4    ... -2.696370e-12  4.347776e-13 -4.160969e-12 -2.368743e-12
#
#                V25           V26           V27           V28    Amount  \
# Time -2.330828e-01 -4.140710e-02 -5.134591e-03 -9.412688e-03 -0.010596
# V1    1.144179e-12  1.835263e-12  7.624804e-12 -9.769215e-13 -0.227709
# V2   -9.423730e-13 -4.129100e-13 -9.856545e-13  2.525513e-12 -0.531409
# V3    5.712956e-13 -2.577274e-12 -5.041444e-12  5.189109e-12 -0.210880
# V4    1.619944e-12 -3.043100e-13 -1.456066e-12 -2.832372e-12  0.098732
#
#          Class
# Time -0.012323
# V1   -0.101347
# V2    0.091289
# V3   -0.192961
# V4    0.133447
#
# [5 rows x 31 columns]

# %%
plt.figure(figsize=(30,30))
g=sns.heatmap(data.corr(),annot=True) # cannot adds text in our heatmap

# %%
X=data.iloc[ : , : -1].values
y=data.iloc[: ,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=43)

# %%
model1 = setup(data = data, target= 'Class') #Model1
# Out:
# <style type="text/css">
# #T_f272a_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f272a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f272a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f272a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f272a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f272a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f272a_row0_col1" class="data row0 col1" >4448</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f272a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f272a_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f272a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f272a_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f272a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f272a_row3_col1" class="data row3 col1" >(284807, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f272a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f272a_row4_col1" class="data row4 col1" >(284807, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f272a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f272a_row5_col1" class="data row5 col1" >(199364, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f272a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f272a_row6_col1" class="data row6 col1" >(85443, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f272a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f272a_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f272a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f272a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f272a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f272a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f272a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f272a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f272a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f272a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f272a_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f272a_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f272a_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_f272a_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f272a_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_f272a_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f272a_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_f272a_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f272a_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_f272a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f272a_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_f272a_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f272a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f272a_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_f272a_row18_col1" class="data row18 col1" >b354</td>
#     </tr>
#   </tbody>
# </table>

# %%
result=compare_models()
# Out:
# <style type="text/css">
# #T_3963f th {
#   text-align: left;
# }
# #T_3963f_row0_col0, #T_3963f_row0_col2, #T_3963f_row0_col3, #T_3963f_row1_col0, #T_3963f_row1_col2, #T_3963f_row1_col3, #T_3963f_row1_col4, #T_3963f_row1_col5, #T_3963f_row1_col6, #T_3963f_row1_col7, #T_3963f_row2_col0, #T_3963f_row2_col1, #T_3963f_row2_col3, #T_3963f_row2_col4, #T_3963f_row2_col5, #T_3963f_row2_col6, #T_3963f_row2_col7, #T_3963f_row3_col0, #T_3963f_row3_col1, #T_3963f_row3_col2, #T_3963f_row3_col3, #T_3963f_row3_col4, #T_3963f_row3_col5, #T_3963f_row3_col6, #T_3963f_row3_col7, #T_3963f_row4_col0, #T_3963f_row4_col1, #T_3963f_row4_col2, #T_3963f_row4_col3, #T_3963f_row4_col4, #T_3963f_row4_col5, #T_3963f_row4_col6, #T_3963f_row4_col7, #T_3963f_row5_col0, #T_3963f_row5_col1, #T_3963f_row5_col2, #T_3963f_row5_col3, #T_3963f_row5_col4, #T_3963f_row5_col5, #T_3963f_row5_col6, #T_3963f_row5_col7, #T_3963f_row6_col0, #T_3963f_row6_col1, #T_3963f_row6_col2, #T_3963f_row6_col3, #T_3963f_row6_col4, #T_3963f_row6_col5, #T_3963f_row6_col6, #T_3963f_row6_col7, #T_3963f_row7_col0, #T_3963f_row7_col1, #T_3963f_row7_col3, #T_3963f_row7_col4, #T_3963f_row7_col5, #T_3963f_row7_col6, #T_3963f_row7_col7, #T_3963f_row8_col0, #T_3963f_row8_col1, #T_3963f_row8_col2, #T_3963f_row8_col3, #T_3963f_row8_col4, #T_3963f_row8_col5, #T_3963f_row8_col6, #T_3963f_row8_col7, #T_3963f_row9_col0, #T_3963f_row9_col1, #T_3963f_row9_col2, #T_3963f_row9_col3, #T_3963f_row9_col4, #T_3963f_row9_col5, #T_3963f_row9_col6, #T_3963f_row9_col7, #T_3963f_row10_col0, #T_3963f_row10_col1, #T_3963f_row10_col2, #T_3963f_row10_col3, #T_3963f_row10_col4, #T_3963f_row10_col5, #T_3963f_row10_col6, #T_3963f_row10_col7, #T_3963f_row11_col0, #T_3963f_row11_col1, #T_3963f_row11_col2, #T_3963f_row11_col3, #T_3963f_row11_col4, #T_3963f_row11_col5, #T_3963f_row11_col6, #T_3963f_row11_col7, #T_3963f_row12_col0, #T_3963f_row12_col1, #T_3963f_row12_col2, #T_3963f_row12_col3, #T_3963f_row12_col4, #T_3963f_row12_col5, #T_3963f_row12_col6, #T_3963f_row12_col7, #T_3963f_row13_col0, #T_3963f_row13_col1, #T_3963f_row13_col2, #T_3963f_row13_col4, #T_3963f_row13_col5, #T_3963f_row13_col6, #T_3963f_row13_col7 {
#   text-align: left;
# }
# #T_3963f_row0_col1, #T_3963f_row0_col4, #T_3963f_row0_col5, #T_3963f_row0_col6, #T_3963f_row0_col7, #T_3963f_row1_col1, #T_3963f_row2_col2, #T_3963f_row7_col2, #T_3963f_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3963f_row0_col8, #T_3963f_row1_col8, #T_3963f_row2_col8, #T_3963f_row3_col8, #T_3963f_row4_col8, #T_3963f_row5_col8, #T_3963f_row6_col8, #T_3963f_row7_col8, #T_3963f_row8_col8, #T_3963f_row10_col8, #T_3963f_row11_col8, #T_3963f_row12_col8, #T_3963f_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3963f_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3963f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3963f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3963f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3963f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3963f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3963f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3963f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3963f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3963f_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3963f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3963f_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_3963f_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_3963f_row0_col1" class="data row0 col1" >0.9995</td>
#       <td id="T_3963f_row0_col2" class="data row0 col2" >0.9462</td>
#       <td id="T_3963f_row0_col3" class="data row0 col3" >0.7677</td>
#       <td id="T_3963f_row0_col4" class="data row0 col4" >0.9550</td>
#       <td id="T_3963f_row0_col5" class="data row0 col5" >0.8501</td>
#       <td id="T_3963f_row0_col6" class="data row0 col6" >0.8499</td>
#       <td id="T_3963f_row0_col7" class="data row0 col7" >0.8555</td>
#       <td id="T_3963f_row0_col8" class="data row0 col8" >134.8340</td>
#     </tr>
#     <tr>
#       <th id="T_3963f_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3963f_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_3963f_row1_col1" class="data row1 col1" >0.9995</td>
#       <td id="T_3963f_row1_col2" class="data row1 col2" >0.9533</td>
#       <td id="T_3963f_row1_col3" class="data row1 col3" >0.7766</td>
#       <td id="T_3963f_row1_col4" class="data row1 col4" >0.9375</td>
#       <td id="T_3963f_row1_col5" class="data row1 col5" >0.8487</td>
#       <td id="T_3963f_row1_col6" class="data row1 col6" >0.8484</td>
#       <td id="T_3963f_row1_col7" class="data row1 col7" >0.8526</td>
#       <td id="T_3963f_row1_col8" class="data row1 col8" >16.1440</td>
#     </tr>
#     <tr>
#       <th id="T_3963f_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_3963f_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3963f_row2_col1" class="data row2 col1" >0.9994</td>
#       <td id="T_3963f_row2_col2" class="data row2 col2" >0.9813</td>
#       <td id="T_3963f_row2_col3" class="data row2 col3" >0.7590</td>
#       <td id="T_3963f_row2_col4" class="data row2 col4" >0.8614</td>
#       <td id="T_3963f_row2_col5" class="data row2 col5" >0.8061</td>
#       <td id="T_3963f_row2_col6" class="data row2 col6" >0.8057</td>
#       <td id="T_3963f_row2_col7" class="data row2 col7" >0.8078</td>
#       <td id="T_3963f_row2_col8" class="data row2 col8" >5.2110</td>
#     </tr>
#     <tr>
#       <th id="T_3963f_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_3963f_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_3963f_row3_col1" class="data row3 col1" >0.9991</td>
#       <td id="T_3963f_row3_col2" class="data row3 col2" >0.9586</td>
#       <td id="T_3963f_row3_col3" class="data row3 col3" >0.6186</td>
#       <td id="T_3963f_row3_col4" class="data row3 col4" >0.8266</td>
#       <td id="T_3963f_row3_col5" class="data row3 col5" >0.7036</td>
#       <td id="T_3963f_row3_col6" class="data row3 col6" >0.7032</td>
#       <td id="T_3963f_row3_col7" class="data row3 col7" >0.7126</td>
#       <td id="T_3963f_row3_col8" class="data row3 col8" >24.1160</td>
#     </tr>
#     <tr>
#       <th id="T_3963f_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_3963f_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_3963f_row4_col1" class="data row4 col1" >0.9991</td>
#       <td id="T_3963f_row4_col2" class="data row4 col2" >0.8792</td>
#       <td id="T_3963f_row4_col3" class="data row4 col3" >0.7588</td>
#       <td id="T_3963f_row4_col4" class="data row4 col4" >0.7522</td>
#       <td id="T_3963f_row4_col5" class="data row4 col5" >0.7533</td>
#       <td id="T_3963f_row4_col6" class="data row4 col6" >0.7528</td>
#       <td id="T_3963f_row4_col7" class="data row4 col7" >0.7540</td>
#       <td id="T_3963f_row4_col8" class="data row4 col8" >23.2010</td>
#     </tr>
#     <tr>
#       <th id="T_3963f_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_3963f_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_3963f_row5_col1" class="data row5 col1" >0.9991</td>
#       <td id="T_3963f_row5_col2" class="data row5 col2" >0.9680</td>
#       <td id="T_3963f_row5_col3" class="data row5 col3" >0.6683</td>
#       <td id="T_3963f_row5_col4" class="data row5 col4" >0.7974</td>
#       <td id="T_3963f_row5_col5" class="data row5 col5" >0.7228</td>
#       <td id="T_3963f_row5_col6" class="data row5 col6" >0.7224</td>
#       <td id="T_3963f_row5_col7" class="data row5 col7" >0.7274</td>
#       <td id="

# %%
print(result)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=4448, verbose=0,
#                        warm_start=False)

# %%
evaluate_model (result)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.classification import plot_model
plot_model(result, plot = 'auc')

# %%
plot_model(result, plot = 'confusion_matrix')

# %%
random_forest = create_model('rf')
# Out:
# <style type="text/css">
# #T_b003e_row10_col0, #T_b003e_row10_col1, #T_b003e_row10_col2, #T_b003e_row10_col3, #T_b003e_row10_col4, #T_b003e_row10_col5, #T_b003e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b003e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b003e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b003e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b003e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b003e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b003e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b003e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b003e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b003e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b003e_row0_col0" class="data row0 col0" >0.9994</td>
#       <td id="T_b003e_row0_col1" class="data row0 col1" >0.9268</td>
#       <td id="T_b003e_row0_col2" class="data row0 col2" >0.7429</td>
#       <td id="T_b003e_row0_col3" class="data row0 col3" >0.8966</td>
#       <td id="T_b003e_row0_col4" class="data row0 col4" >0.8125</td>
#       <td id="T_b003e_row0_col5" class="data row0 col5" >0.8122</td>
#       <td id="T_b003e_row0_col6" class="data row0 col6" >0.8158</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b003e_row1_col0" class="data row1 col0" >0.9996</td>
#       <td id="T_b003e_row1_col1" class="data row1 col1" >0.9561</td>
#       <td id="T_b003e_row1_col2" class="data row1 col2" >0.8286</td>
#       <td id="T_b003e_row1_col3" class="data row1 col3" >0.9667</td>
#       <td id="T_b003e_row1_col4" class="data row1 col4" >0.8923</td>
#       <td id="T_b003e_row1_col5" class="data row1 col5" >0.8921</td>
#       <td id="T_b003e_row1_col6" class="data row1 col6" >0.8948</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b003e_row2_col0" class="data row2 col0" >0.9992</td>
#       <td id="T_b003e_row2_col1" class="data row2 col1" >0.9118</td>
#       <td id="T_b003e_row2_col2" class="data row2 col2" >0.6857</td>
#       <td id="T_b003e_row2_col3" class="data row2 col3" >0.8276</td>
#       <td id="T_b003e_row2_col4" class="data row2 col4" >0.7500</td>
#       <td id="T_b003e_row2_col5" class="data row2 col5" >0.7496</td>
#       <td id="T_b003e_row2_col6" class="data row2 col6" >0.7529</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b003e_row3_col0" class="data row3 col0" >0.9994</td>
#       <td id="T_b003e_row3_col1" class="data row3 col1" >0.9404</td>
#       <td id="T_b003e_row3_col2" class="data row3 col2" >0.7143</td>
#       <td id="T_b003e_row3_col3" class="data row3 col3" >0.9259</td>
#       <td id="T_b003e_row3_col4" class="data row3 col4" >0.8065</td>
#       <td id="T_b003e_row3_col5" class="data row3 col5" >0.8062</td>
#       <td id="T_b003e_row3_col6" class="data row3 col6" >0.8130</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b003e_row4_col0" class="data row4 col0" >0.9998</td>
#       <td id="T_b003e_row4_col1" class="data row4 col1" >0.9845</td>
#       <td id="T_b003e_row4_col2" class="data row4 col2" >0.8824</td>
#       <td id="T_b003e_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_b003e_row4_col4" class="data row4 col4" >0.9375</td>
#       <td id="T_b003e_row4_col5" class="data row4 col5" >0.9374</td>
#       <td id="T_b003e_row4_col6" class="data row4 col6" >0.9392</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b003e_row5_col0" class="data row5 col0" >0.9996</td>
#       <td id="T_b003e_row5_col1" class="data row5 col1" >0.9547</td>
#       <td id="T_b003e_row5_col2" class="data row5 col2" >0.7647</td>
#       <td id="T_b003e_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_b003e_row5_col4" class="data row5 col4" >0.8667</td>
#       <td id="T_b003e_row5_col5" class="data row5 col5" >0.8665</td>
#       <td id="T_b003e_row5_col6" class="data row5 col6" >0.8743</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b003e_row6_col0" class="data row6 col0" >0.9996</td>
#       <td id="T_b003e_row6_col1" class="data row6 col1" >0.9696</td>
#       <td id="T_b003e_row6_col2" class="data row6 col2" >0.7647</td>
#       <td id="T_b003e_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_b003e_row6_col4" class="data row6 col4" >0.8667</td>
#       <td id="T_b003e_row6_col5" class="data row6 col5" >0.8665</td>
#       <td id="T_b003e_row6_col6" class="data row6 col6" >0.8743</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b003e_row7_col0" class="data row7 col0" >0.9996</td>
#       <td id="T_b003e_row7_col1" class="data row7 col1" >0.9246</td>
#       <td id="T_b003e_row7_col2" class="data row7 col2" >0.7647</td>
#       <td id="T_b003e_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_b003e_row7_col4" class="data row7 col4" >0.8667</td>
#       <td id="T_b003e_row7_col5" class="data row7 col5" >0.8665</td>
#       <td id="T_b003e_row7_col6" class="data row7 col6" >0.8743</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b003e_row8_col0" class="data row8 col0" >0.9995</td>
#       <td id="T_b003e_row8_col1" class="data row8 col1" >0.9246</td>
#       <td id="T_b003e_row8_col2" class="data row8 col2" >0.7059</td>
#       <td id="T_b003e_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_b003e_row8_col4" class="data row8 col4" >0.8276</td>
#       <td id="T_b003e_row8_col5" class="data row8 col5" >0.8273</td>
#       <td id="T_b003e_row8_col6" class="data row8 col6" >0.8400</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b003e_row9_col0" class="data row9 col0" >0.9996</td>
#       <td id="T_b003e_row9_col1" class="data row9 col1" >0.9692</td>
#       <td id="T_b003e_row9_col2" class="data row9 col2" >0.8235</td>
#       <td id="T_b003e_row9_col3" class="data row9 col3" >0.9333</td>
#       <td id="T_b003e_row9_col4" class="data row9 col4" >0.8750</td>
#       <td id="T_b003e_row9_col5" class="data row9 col5" >0.8748</td>
#       <td id="T_b003e_row9_col6" class="data row9 col6" >0.8765</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b003e_row10_col0" class="data row10 col0" >0.9995</td>
#       <td id="T_b003e_row10_col1" class="data row10 col1" >0.9462</td>
#       <td id="T_b003e_row10_col2" class="data row10 col2" >0.7677</td>
#       <td id="T_b003e_row10_col3" class="data row10 col3" >0.9550</td>
#       <td id="T_b003e_row10_col4" class="data row10 col4" >0.8501</td>
#       <td id="T_b003e_row10_col5" class="data row10 col5" >0.8499</td>
#       <td id="T_b003e_row10_col6" class="data row10 col6" >0.8555</td>
#     </tr>
#     <tr>
#       <th id="T_b003e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b003e_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_b003e_row11_col1" class="data row11 col1" >0.0229</td>
#       <td id="T_b003e_row11_col2" class="data row11 col2" >0.0583</td>
#       <td id="T_b003e_row11_col3" class="data row11 col3" >0.0559</td>
#       <td id="T_b003e_row11_col4

# %%
random_forest
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=4448, verbose=0,
#                        warm_start=False)

# %%
pred_holdout = predict_model(random_forest,data= data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0fbb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fbb4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0fbb4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0fbb4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0fbb4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0fbb4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0fbb4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0fbb4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0fbb4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fbb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fbb4_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_0fbb4_row0_col1" class="data row0 col1" >0.9999</td>
#       <td id="T_0fbb4_row0_col2" class="data row0 col2" >0.9855</td>
#       <td id="T_0fbb4_row0_col3" class="data row0 col3" >0.9370</td>
#       <td id="T_0fbb4_row0_col4" class="data row0 col4" >0.9872</td>
#       <td id="T_0fbb4_row0_col5" class="data row0 col5" >0.9614</td>
#       <td id="T_0fbb4_row0_col6" class="data row0 col6" >0.9614</td>
#       <td id="T_0fbb4_row0_col7" class="data row0 col7" >0.9617</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834784 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V23       V24  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.110474  0.066928
# 1      -0.082361 -0.078803  0.085102 -0.255425  ...  0.101288 -0.339846
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.909412 -0.689281
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.190321 -1.175575
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.137458  0.141267
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  1.014480 -0.509348
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.012463 -1.016226
# 284804  3.031260 -0.296827  0.708417  0.432454  ... -0.037501  0.640134
# 284805  0.623708 -0.686180  0.679145  0.392087  ... -0.163298  0.123205
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.376777  0.008797
#
#              V25       V26       V27       V28      Amount  Class  \
# 0       0.128539 -0.189115  0.133558 -0.021053  149.619995      0
# 1       0.167170  0.125895 -0.008983  0.014724    2.690000      0
# 2      -0.327642 -0.139097 -0.055353 -0.059752  378.660004      0
# 3       0.647376 -0.221929  0.062723  0.061458  123.500000      0
# 4      -0.206010  0.502292  0.219422  0.215153   69.989998      0
# ...          ...       ...       ...       ...         ...    ...
# 284802  1.436807  0.250034  0.943651  0.823731    0.770000      0
# 284803 -0.606624 -0.395255  0.068472 -0.053527   24.790001      0
# 284804  0.265745 -0.087371  0.004455 -0.026561   67.879997      0
# 284805 -0.569159  0.546668  0.108821  0.104533   10.000000      0
# 284806 -0.473649 -0.818267 -0.002415  0.013649  217.000000      0
#
#         prediction_label  prediction_score
# 0                      0              1.00
# 1                      0              1.00
# 2                      0              0.99
# 3                      0              1.00
# 4                      0              1.00
# ...                  ...               ...
# 284802                 0              1.00
# 284803                 0              1.00
# 284804                 0              1.00
# 284805                 0              1.00
# 284806                 0              1.00
#
# [284807 rows x 33 columns]
